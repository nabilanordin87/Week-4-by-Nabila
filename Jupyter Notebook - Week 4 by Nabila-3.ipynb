# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Name: Nabila binti Nordin
# Desired occupation: Data scientist

# %% [markdown]
# I am interested in data science because it makes me want to learn something new which is totally differ from my background.

# %% [markdown]
# nabila is smart

# %%
1 + 1
# Out:
# 2
